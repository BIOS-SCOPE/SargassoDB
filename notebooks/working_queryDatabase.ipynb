# %% [markdown]
# ## Use database
# Krista 31 March 2026

# %%
# %reset -f

# %%
# setup
import pandas as pd
import sqlalchemy as db
from sqlalchemy import create_engine, inspect, MetaData, Table
from sqlalchemy.orm import sessionmaker, declarative_base
from sqlalchemy import text
from sqlalchemy import select

import os

# %%
# sqlite:///relative/path/to/file.db
database_url = 'sqlite:///../sql_app.db'
#database_url = 'sqlite+pysqlite:///../sql_app.db'

#engine = db.create_engine(database_url,echo=True)
engine = db.create_engine(database_url)
connection = engine.connect()

stmt = text('select cruise_id from cruises')
result = connection.execute(stmt)

first_record = result.first()
print(first_record)
# Out:
# ('AE1602',)

# %%
result = connection.execute(stmt)

for first in result:
    print("{}".format(first))
# Out:
# ('AE1602',)
# ('AE1603',)
# ('AE1605',)
# ('AE1608',)
# ('AE1611',)
# ('AE1614',)
# ('AE1615',)
# ('AE1618',)
# ('AE1621',)
# ('AE1624',)
# ('AE1627',)
# ('AE1629',)
# ('AE1701',)
# ('EN592',)
# ('AE1704',)
# ('AE1707',)
# ('AE1709',)
# ('AE1713',)
# ('AE1715',)
# ('AE1718',)
# ('AE1722',)
# ('AE1726',)
# ('AE1728',)
# ('AE1802',)
# ('AE1805',)
# ('AE1807',)
# ('AE1810',)
# ('AE1814',)
# ('AE1817',)
# ('AE1820',)
# ('AE1822',)
# ('AE1825',)
# ('AE1829',)
# ('AE1831',)
# ('AE1836',)
# ('AE1902',)
# ('EN629',)
# ('EN631',)
# ('AE1905',)
# ('AE1909',)
# ('AE1912',)
# ('AE1917',)
# ('AE1921',)
# ('AE1923',)
# ('AE1927',)
# ('AE1930',)
# ('AE1932',)
# ('AE2002',)
# ('AE2005',)
# ('AE2009',)
# ('AE2010',)
# ('AE2012',)
# ('AE2015',)
# ('AE2017',)
# ('AE2019',)
# ('AE2021',)
# ('AE2101',)
# ('AE2102',)
# ('AE2103',)
# ('AE2109',)
# ('AE2110',)
# ('AE2112',)
# ('AE2116',)
# ('AE2117',)
# ('AE2119',)
# ('AE2124',)
# ('AE2126',)
# ('AE2201',)
# ('AE1604',)
# ('AE1705',)
# ('AE1708',)
# ...

# %%
result = connection.execute(stmt)
all_records = result.all()         # returns a list of the row/records object
all_records[1]._mapping            # for the second element, retrieve the dictionay interface
# Out:
# {'cruise_id': 'AE1603'}

# %%
with engine.connect() as connection:
    result = connection.execute(text('select cruise_id from cruises'))
    all_rows = result.all()
    print(len(all_rows))
# Out:
# 348

# %%
with engine.connect() as connection:
    result = connection.execute(text('select * from cruises where cruise_id= :cruise_id'),{'cruise_id':'AE1627'})
    print(result.first())
    connection.commit()     # mark the change as successful.  Database will commit the change
    
# with engine.connect() as connection:
#     result = connection.execute(text("select * from artists where artistid=99999"))
#     print(result.first())
# Out:
# (11, 'BATS', 'AE1627', None, None, None, None, None)

# %%
with engine.connect() as connection:
    query = text('select * from cruises where cruise_id= :cruise_id')
    values = [{'cruise_id' : 'AE1627'}]
    result = connection.execute(query,values)
    
    #then make a pandas dataframe from result
    df = pd.DataFrame(result.all())
    df.columns = result.keys()
    print(df)
#    connection.commit()     # mark the change as successful.  Database will commit the change
# Out:
#     id program cruise_id station target_lat target_long departure_date  \
# 0   11    BATS    AE1627    None       None        None           None
# 1   98    BATS    AE1627    None       None        None           None
# 2  185    BATS    AE1627    None       None        None           None
# 3  272    BATS    AE1627    None       None        None           None
#
#   return_date
# 0        None
# 1        None
# 2        None
# 3        None

# %%
with engine.connect() as connection:
    result = connection.execute(text('select cruise_id FROM cruises WHERE cruise_id = :cruise_id'),
                                [{'cruise_id': 'AE1627'}])
    for row in result:
        print(f"x: {row.cruise_id}")
# Out:
# x: AE1627
# x: AE1627
# x: AE1627
# x: AE1627

# %%
from sqlalchemy.orm import Session
stmt = text('SELECT cruise_id FROM cruises WHERE cruise_id = :cruise_id')
with Session(engine) as session:
    result = session.execute(stmt,{'cruise_id': 'AE1627'})
    for row in result:
        print(f"x: {row.cruise_id}")
# Out:
# x: AE1627
# x: AE1627
# x: AE1627
# x: AE1627

# %%
from sqlalchemy import MetaData
metadata = MetaData()
metadata.reflect(bind=engine)
print(f"Tables found: {metadata.tables.keys()}") #
# Out:
# Tables found: dict_keys(['asv_metadatas', 'asv_rel_abundances', 'asv_samples', 'niskins', 'casts', 'cruises', 'users'])

# %%
my_table = metadata.tables['asv_metadatas']

# To inspect column details of a table:
for column in my_table.columns:
    print(f"Column name: {column.name}, Type: {column.type}")
# Out:
# Column name: id, Type: INTEGER
# Column name: sequence, Type: VARCHAR
# Column name: tax_kingdom, Type: VARCHAR(300)
# Column name: tax_phylum, Type: VARCHAR(300)
# Column name: tax_class, Type: VARCHAR(300)
# Column name: tax_order, Type: VARCHAR(300)
# Column name: tax_family, Type: VARCHAR(300)
# Column name: tax_genus, Type: VARCHAR(300)
# Column name: tax_comboname, Type: VARCHAR(1000)

# %%
#so for me, here are the keys (in metadata.table)
metadata.tables.keys()
# Out:
# dict_keys(['asv_metadatas', 'asv_rel_abundances', 'asv_samples', 'niskins', 'casts', 'cruises', 'users'])

# %%
metadata.tables
# Out:
# FacadeDict({'asv_metadatas': Table('asv_metadatas', MetaData(), Column('id', INTEGER(), table=<asv_metadatas>, primary_key=True, nullable=False), Column('sequence', VARCHAR(), table=<asv_metadatas>, nullable=False), Column('tax_kingdom', VARCHAR(length=300), table=<asv_metadatas>), Column('tax_phylum', VARCHAR(length=300), table=<asv_metadatas>), Column('tax_class', VARCHAR(length=300), table=<asv_metadatas>), Column('tax_order', VARCHAR(length=300), table=<asv_metadatas>), Column('tax_family', VARCHAR(length=300), table=<asv_metadatas>), Column('tax_genus', VARCHAR(length=300), table=<asv_metadatas>), Column('tax_comboname', VARCHAR(length=1000), table=<asv_metadatas>), schema=None), 'asv_rel_abundances': Table('asv_rel_abundances', MetaData(), Column('id', INTEGER(), table=<asv_rel_abundances>, primary_key=True, nullable=False), Column('abundance', FLOAT(), table=<asv_rel_abundances>, nullable=False), Column('asv_metadata_id', INTEGER(), ForeignKey('asv_metadatas.id'), table=<asv_r
# ...

# %% [markdown]
# # starting again

# %%
inspector = inspect(engine)
tables = inspector.get_table_names()
print(tables)
# Out:
# ['asv_metadatas', 'asv_rel_abundances', 'asv_samples', 'casts', 'cruises', 'niskins', 'users']

# %%
#from sqlalchemy import MetaData, Table, select

metadata_obj = MetaData()
# Reflect a specific table from the engine
user_table = Table("cruises", metadata_obj, autoload_with=engine)

# %%
user_table
# Out:
# Table('cruises', MetaData(), Column('id', INTEGER(), table=<cruises>, primary_key=True, nullable=False), Column('program', VARCHAR(), table=<cruises>), Column('cruise_id', VARCHAR(), table=<cruises>), Column('station', VARCHAR(), table=<cruises>), Column('target_lat', VARCHAR(), table=<cruises>), Column('target_long', VARCHAR(), table=<cruises>), Column('departure_date', DATE(), table=<cruises>), Column('return_date', DATE(), table=<cruises>), schema=None)

# %%
user_table_cruises = Table("cruises", metadata_obj, autoload_with=engine)
user_table_niskins = Table('niskins',metadata_obj,autoload_with = engine)
user_table_asv_samples = Table('asv_samples',metadata_obj,autoload_with=engine)
user_table_casts = Table('casts',metadata_obj,autoload_with=engine)

# %%
user_table_niskins
# Out:
# Table('niskins', MetaData(), Column('id', INTEGER(), table=<niskins>, primary_key=True, nullable=False), Column('bottle_id', INTEGER(), table=<niskins>, nullable=False), Column('old_bottle_id', VARCHAR(), table=<niskins>), Column('niskin_number', INTEGER(), table=<niskins>), Column('location_gps_lat', FLOAT(), table=<niskins>), Column('location_gps_long', FLOAT(), table=<niskins>), Column('date_time_triggered', DATETIME(), table=<niskins>), Column('depth_triggered', FLOAT(), table=<niskins>), Column('nominal_depth', INTEGER(), table=<niskins>), Column('temperature', FLOAT(), table=<niskins>), Column('cast_id', INTEGER(), ForeignKey('casts.id'), table=<niskins>), schema=None)

# %%
user_table_asv_samples
# Out:
# Table('asv_samples', MetaData(), Column('id', INTEGER(), table=<asv_samples>, primary_key=True, nullable=False), Column('data_type', VARCHAR(length=10), table=<asv_samples>), Column('sample_name', VARCHAR(), table=<asv_samples>), Column('fwd_primer', VARCHAR(), table=<asv_samples>), Column('rev_primer', VARCHAR(), table=<asv_samples>), Column('data_url', VARCHAR(), table=<asv_samples>), Column('dada2name', VARCHAR(), table=<asv_samples>), Column('niskin_id', INTEGER(), ForeignKey('niskins.id'), table=<asv_samples>), schema=None)

# %%
#from sqlalchemy import select
#stmt = select(Cruise).where(Cruise.c.cruise_id == "AE1627")
stmt = select(user_table).where(user_table.c.cruise_id == "AE1627")
print(stmt)
# Out:
# SELECT cruises.id, cruises.program, cruises.cruise_id, cruises.station, cruises.target_lat, cruises.target_long, cruises.departure_date, cruises.return_date
# FROM cruises
# WHERE cruises.cruise_id = :cruise_id_1

# %%
with engine.connect() as conn:
    for row in conn.execute(stmt):
        print(row)
# Out:
# (11, 'BATS', 'AE1627', None, None, None, None, None)
# (98, 'BATS', 'AE1627', None, None, None, None, None)
# (185, 'BATS', 'AE1627', None, None, None, None, None)
# (272, 'BATS', 'AE1627', None, None, None, None, None)

# %%
stmt = select(user_table).where(user_table.c.cruise_id == "AE1627")
with Session(engine) as session:
    for row in session.execute(stmt):
        print(row)
# Out:
# (11, 'BATS', 'AE1627', None, None, None, None, None)
# (98, 'BATS', 'AE1627', None, None, None, None, None)
# (185, 'BATS', 'AE1627', None, None, None, None, None)
# (272, 'BATS', 'AE1627', None, None, None, None, None)

# %%
print(select(user_table))
# Out:
# SELECT cruises.id, cruises.program, cruises.cruise_id, cruises.station, cruises.target_lat, cruises.target_long, cruises.departure_date, cruises.return_date
# FROM cruises

# %%
print(select(user_table.c["program", "cruise_id"]))
# Out:
# SELECT cruises.program, cruises.cruise_id
# FROM cruises

# %%
print(select(user_table_asv_samples.c["id", "niskin_id"]))
# Out:
# SELECT asv_samples.id, asv_samples.niskin_id
# FROM asv_samples

# %%
print(select(user_table_cruises.c.id))
# Out:
# SELECT cruises.id
# FROM cruises

# %%
user_table_asv_samples
# Out:
# Table('asv_samples', MetaData(), Column('id', INTEGER(), table=<asv_samples>, primary_key=True, nullable=False), Column('data_type', VARCHAR(length=10), table=<asv_samples>), Column('sample_name', VARCHAR(), table=<asv_samples>), Column('fwd_primer', VARCHAR(), table=<asv_samples>), Column('rev_primer', VARCHAR(), table=<asv_samples>), Column('data_url', VARCHAR(), table=<asv_samples>), Column('dada2name', VARCHAR(), table=<asv_samples>), Column('niskin_id', INTEGER(), ForeignKey('niskins.id'), table=<asv_samples>), schema=None)

# %%
print(select(user_table_asv_samples.c.niskin_id))
# Out:
# SELECT asv_samples.niskin_id
# FROM asv_samples

# %%
stmt = select(user_table_asv_samples, user_table_niskins).join_from(
    user_table_asv_samples, user_table_niskins, user_table_niskins.c.id == user_table_asv_samples.c.niskin_id
)

# %%
with Session(engine) as session:
    for row in session.execute(stmt):
        print(row)
# Out:
# (1, None, 'C4_1_S25', None, None, None, 'lane1_s025_indexN704_A_S502_A_TCCTGAGC_CTCTCTAT_C4_1_S25', 13068, 13068, 9170300402, 'BSAE1703.4.2', 2, 31.6661, 64.1679, None, 4.106, 1, 20.1551, 584)
# (2, None, 'C4_40_S26', None, None, None, 'lane1_s026_indexN704_A_S503_A_TCCTGAGC_TATCCTCT_C4_40_S26', 13070, 13070, 9170300404, 'BSAE1703.4.4', 4, 31.6661, 64.1679, None, 40.386, 40, 20.1415, 584)
# (3, None, 'C4_80_S27', None, None, None, 'lane1_s027_indexN704_A_S505_A_TCCTGAGC_GTAAGGAG_C4_80_S27', 13072, 13072, 9170300406, 'BSAE1703.4.6', 6, 31.6661, 64.1679, None, 79.016, 80, 20.1344, 584)
# (4, None, 'C4_120_S28', None, None, None, 'lane1_s028_indexN704_A_S506_A_TCCTGAGC_ACTGCATA_C4_120_S28', 13074, 13074, 9170300408, 'BSAE1703.4.8', 8, 31.6661, 64.1679, None, 121.033, 120, 20.1146, 584)
# ...

# %%
stmt = select(user_table_asv_samples, user_table_niskins.c.nominal_depth).join_from(
    user_table_asv_samples, user_table_niskins, user_table_niskins.c.id == user_table_asv_samples.c.niskin_id
)

with Session(engine) as session:
    for row in session.execute(stmt):
        print(row)
# Out:
# (1, None, 'C4_1_S25', None, None, None, 'lane1_s025_indexN704_A_S502_A_TCCTGAGC_CTCTCTAT_C4_1_S25', 13068, 1)
# (2, None, 'C4_40_S26', None, None, None, 'lane1_s026_indexN704_A_S503_A_TCCTGAGC_TATCCTCT_C4_40_S26', 13070, 40)
# (3, None, 'C4_80_S27', None, None, None, 'lane1_s027_indexN704_A_S505_A_TCCTGAGC_GTAAGGAG_C4_80_S27', 13072, 80)
# (4, None, 'C4_120_S28', None, None, None, 'lane1_s028_indexN704_A_S506_A_TCCTGAGC_ACTGCATA_C4_120_S28', 13074, 120)
# (5, None, 'C4_160_S29', None, None, None, 'lane1_s029_indexN704_A_S507_A_TCCTGAGC_AAGGAGTA_C4_160_S29', 13076, 160)
# (6, None, 'C4_200_S30', None, None, None, 'lane1_s030_indexN704_A_S508_A_TCCTGAGC_CTAAGCCT_C4_200_S30', 13078, 200)
# (7, None, 'C4_250_S31', None, None, None, 'lane1_s031_indexN704_A_S510_A_TCCTGAGC_CGTCTAAT_C4_250_S31', 13080, 250)
# (8, None, 'C4_300_S32', None, None, None, 'lane1_s032_indexN704_A_S511_A_TCCTGAGC_TCTCTCCG_C4_300_S32', 13082, 300)
# ...

# %%
#remember that this number is cast_id...which is not cast (though I assume there is a way to put another query in here to get the cast number)
stmt = select(user_table_asv_samples.c.sample_name, user_table_asv_samples.c.niskin_id, user_table_niskins.c.nominal_depth, user_table_niskins.c.cast_id).join_from(
    user_table_asv_samples, user_table_niskins, user_table_niskins.c.id == user_table_asv_samples.c.niskin_id
)

with Session(engine) as session:
    for row in session.execute(stmt):
        print(row)
# Out:
# ('C4_1_S25', 13068, 1, 584)
# ('C4_40_S26', 13070, 40, 584)
# ('C4_80_S27', 13072, 80, 584)
# ('C4_120_S28', 13074, 120, 584)
# ('C4_160_S29', 13076, 160, 584)
# ('C4_200_S30', 13078, 200, 584)
# ('C4_250_S31', 13080, 250, 584)
# ('C4_300_S32', 13082, 300, 584)
# ('C8_1_S33', 13139, 1, 588)
# ('C8_40_S34', 13141, 40, 588)
# ('C8_80_S35', 13143, 80, 588)
# ('C8_120_S36', 13145, 120, 588)
# ('C8_160_S37', 13147, 160, 588)
# ('C8_200_S38', 13149, 200, 588)
# ('C8_250_S39', 13151, 250, 588)
# ('C8_300_S40', 13153, 300, 588)
# ('C11_1_S41', 13195, 1, 591)
# ('C11_40_S42', 13197, 40, 591)
# ('C11_80_S43', 13199, 80, 591)
# ('C11_120_S44', 13201, 120, 591)
# ('C11_160_S45', 13203, 160, 591)
# ('C11_200_S46', 13205, 200, 591)
# ('C11_250_S47', 13207, 250, 591)
# ('C11_300_S48', 13209, 300, 591)
# ('C14_1_S49', 13267, 1, 594)
# ('C14_40_S50', 13269, 40, 594)
# ('C14_80_S51', 13271, 80, 594)
# ('C14_120_S52', 13273, 120, 594)
# ('C14_160_S53', 13275, 160, 594)
# ...

# %%
print(stmt)
# Out:
# SELECT asv_samples.sample_name, asv_samples.niskin_id, niskins.nominal_depth, niskins.cast_id
# FROM asv_samples JOIN niskins ON niskins.id = asv_samples.niskin_id

# %%
user_table_ni
# Out:
# Table('casts', MetaData(), Column('id', INTEGER(), table=<casts>, primary_key=True, nullable=False), Column('cast_number', INTEGER(), table=<casts>), Column('cast_date', DATE(), table=<casts>), Column('mixed_layer_depth_value', FLOAT(), table=<casts>), Column('mixed_layer_depth_method', VARCHAR(), table=<casts>, server_default=DefaultClause(<sqlalchemy.sql.elements.TextClause object at 0x00000182F2592760>, for_update=False)), Column('cruise_id', INTEGER(), ForeignKey('cruises.id'), table=<casts>), schema=None)

# %%
#remember that this number is cast_id...which is not cast (though I assume there is a way to put another query in here to get the cast number)
stmt = select(
    user_table_niskins, 
    user_table_casts
 ).join_from(
    user_table_niskins,
    user_table_casts,
    user_table_niskins.c.cast_id == user_table_casts.c.id
)

with Session(engine) as session:
    for row in session.execute(stmt):
        print(row)
# Out:
# (1, 1032100301, '1032100301', 1, 31.679, 64.18, None, 4.4, 1, 21.124, 1, 1, 3, datetime.date(2016, 3, 8), None, 'dens_T2', 1)
# (2, 1032100302, '1032100302', 2, 31.679, 64.18, None, 11.1, 10, 21.136, 1, 1, 3, datetime.date(2016, 3, 8), None, 'dens_T2', 1)
# (3, 1032100303, '1032100303', 3, 31.679, 64.18, None, 20.6, 20, 21.137, 1, 1, 3, datetime.date(2016, 3, 8), None, 'dens_T2', 1)
# (4, 1032100304, '1032100304', 4, 31.679, 64.18, None, 40.4, 40, 21.142, 1, 1, 3, datetime.date(2016, 3, 8), None, 'dens_T2', 1)
# (5, 1032100305, '1032100305', 5, 31.679, 64.18, None, 60.2, 60, 21.131, 1, 1, 3, datetime.date(2016, 3, 8), None, 'dens_T2', 1)
# (6, 1032100306, '1032100306', 6, 31.679, 64.18, None, 81.7, 80, 21.124, 1, 1, 3, datetime.date(2016, 3, 8), None, 'dens_T2', 1)
# (7, 1032100307, '1032100307', 7, 31.679, 64.18, None, 97.5, 100, 21.07, 1, 1, 3, datetime.date(2016, 3, 8), None, 'dens_T2', 1)
# ...

# %%
#remember need .c. to indicate I am giving the name of a column
subq_stmt = select(
    user_table_niskins.c.bottle_id, 
    user_table_niskins.c.cast_id,
    user_table_casts.c.cast_number
 ).join_from(
    user_table_niskins,
    user_table_casts,
    user_table_niskins.c.cast_id == user_table_casts.c.id
)

with Session(engine) as session:
    for row in session.execute(subq_stmt):
        print(row)
# Out:
# (1032100301, 1, 3)
# (1032100302, 1, 3)
# (1032100303, 1, 3)
# (1032100304, 1, 3)
# (1032100305, 1, 3)
# (1032100306, 1, 3)
# (1032100307, 1, 3)
# (1032100308, 1, 3)
# (1032100309, 1, 3)
# (1032100310, 1, 3)
# (1032100311, 1, 3)
# (1032100312, 1, 3)
# (1032100313, 1, 3)
# (1032100314, 1, 3)
# (1032100315, 1, 3)
# (1032100316, 1, 3)
# (1032100317, 1, 3)
# (1032100318, 1, 3)
# (1032100319, 1, 3)
# (1032100320, 1, 3)
# (1032100321, 1, 3)
# (1032100322, 1, 3)
# (1032100323, 1, 3)
# (1032100324, 1, 3)
# (1032100401, 2, 4)
# (1032100402, 2, 4)
# (1032100403, 2, 4)
# (1032100404, 2, 4)
# (1032100405, 2, 4)
# (1032100406, 2, 4)
# (1032100407, 2, 4)
# (1032100408, 2, 4)
# (1032100409, 2, 4)
# (1032100410, 2, 4)
# (1032100411, 2, 4)
# (1032100412, 2, 4)
# (1032100413, 2, 4)
# (1032100414, 2, 4)
# (1032100415, 2, 4)
# (1032100416, 2, 4)
# (1032100417, 2, 4)
# (1032100418, 2, 4)
# (1032100419, 2, 4)
# (1032100420, 2, 4)
# (1032100421, 2, 4)
# (1032100422, 2, 4)
# (1032100423, 2, 4)
# ...

# %%
raise SystemExit("Stop execution here")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stop execution here
# C:\Users\LaneyLab\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# Stick some code below this spot as a holding zone

# %%
from sqlalchemy.engine import reflection

# # Create connection string & engine
# connection_string = "sqlite:///my_existing_database.db"
# engine = sa.create_engine(connection_string)

# Performs database schema inspection
# inspector = reflection.Inspector.from_engine(engine) #deprecated
inspector = inspect(engine)

# Get a list of all table names
table_names = inspector.get_table_names()
print(f"Table names: {table_names}")

# %%
# Get column information for a specific table
for column in inspector.get_columns('asv_metadatas'):
    print(column['name'], column['type'], column['nullable'])

# You can also get other info
print(inspector.get_foreign_keys('users'))
print(inspector.get_indexes('users'))

# %%
engine = create_engine(database_url)
inspector = inspect(engine)

# Get a list of table names
table_names = inspector.get_table_names()

print("Tables in the database:")
for table_name in table_names:
    print(f"- {table_name}")

# %%
#mmmm this gives me all rows in the table
# Assuming a 'users' table is already defined or reflected
metadata = MetaData()
users_table = db.Table('cruises', metadata, autoload_with=engine)

# Build the query: Equivalent to 'SELECT * FROM users'
query = db.select(users_table)

# Execute the query and fetch results
with engine.connect() as connection:
    result = connection.execute(query)
    # Fetch all results as a list of Row objects
    rows = result.fetchall()
    for row in rows:
        print(row)

# Filter example: Equivalent to 'SELECT * FROM users WHERE name = "Alice"'
query = db.select(users_table).where(users_table.columns.program == 'BIOSSCOPE')
with engine.connect() as connection:
    result = connection.execute(query).fetchall()

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# 1. Create the engine (replace with your database URI)
# Example URIs: 'sqlite:///existing_db.sqlite' or 'postgresql://user:pass@host/dbname'
engine = create_engine("sqlite:///../sql_app.db")

# 2. Use automap to reflect the schema
Base = automap_base()
Base.prepare(autoload_with=engine)

# 3. Access the generated classes (tables)
# Replace 'users' with the actual name of a table in your database
# User = Base.classes.users
User = Base.classes.cruises

# 4. Create a session and use it
session = Session(engine)
